# %% [markdown]
# * https://seaborn.pydata.org/examples/faceted_histogram.html

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
sns.set(style="darkgrid")
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")
tips.shape
# Out:
# (244, 7)

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
bins = np.linspace(0, 60, 13)
bins
# Out:
# array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45., 50., 55., 60.])

# %%
g = sns.FacetGrid(tips, row="sex", col="time", margin_titles=True)
g.map(plt.hist, "total_bill", bins=bins)

# %%
g = sns.FacetGrid(tips, row="sex", col="time", margin_titles=True)
g.map(plt.scatter, "tip", "total_bill")

# %%
g = sns.FacetGrid(tips, row="sex", col="time", margin_titles=True)
bins = np.linspace(0, 60, 13)
g.map(plt.hist, "total_bill", color="steelblue", bins=bins)

# %%
g = sns.FacetGrid(tips, row="time", col="day")
g.map(sns.scatterplot, "total_bill", "tip")

# %%
g = sns.FacetGrid(tips, row="time", col="day")
g.map(sns.regplot, "total_bill", "tip")

# %%
g = sns.FacetGrid(tips, row="time", col="day")
g.map(sns.barplot, "smoker", "total_bill")
# Out:
# /Users/corazzon/codes/jupyter/lib/python3.6/site-packages/seaborn/axisgrid.py:715: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g = sns.FacetGrid(tips, row="time", col="day")
g.map(sns.swarmplot, "smoker", "total_bill", palette="muted")
# Out:
# /Users/corazzon/codes/jupyter/lib/python3.6/site-packages/seaborn/axisgrid.py:715: UserWarning: Using the swarmplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g = sns.FacetGrid(tips, row="time", col="day")
g.map(sns.boxplot, "smoker", "total_bill", palette="muted")
# Out:
# /Users/corazzon/codes/jupyter/lib/python3.6/site-packages/seaborn/axisgrid.py:715: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g = sns.FacetGrid(tips, row="time", col="day")
g.map(sns.violinplot, "smoker", "total_bill", palette="muted")
# Out:
# /Users/corazzon/codes/jupyter/lib/python3.6/site-packages/seaborn/axisgrid.py:715: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
tips.pivot_table(index="time", columns="day", 
                 values="total_bill", aggfunc="count")
# Out:
# day     Thur   Fri   Sat   Sun
# time
# Lunch   61.0   7.0   NaN   NaN
# Dinner   1.0  12.0  87.0  76.0

# %%
c = pd.crosstab(tips["time"], tips["day"])
c
# Out:
# day     Thur  Fri  Sat  Sun
# time
# Lunch     61    7    0    0
# Dinner     1   12   87   76

# %%
n = pd.crosstab(tips["time"], tips["day"], normalize=True)
n
# Out:
# day         Thur       Fri       Sat       Sun
# time
# Lunch   0.250000  0.028689  0.000000  0.000000
# Dinner  0.004098  0.049180  0.356557  0.311475

# %%
plt.figure(figsize=(7, 2))
sns.heatmap(c, annot=True, cmap="Blues")

# %%
plt.figure(figsize=(7, 2))
sns.heatmap(n, annot=True, cmap="Blues")
