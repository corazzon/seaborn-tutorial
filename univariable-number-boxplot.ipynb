# %% [markdown]
# ## 단변수
# * 변수가 하나일 때
# * 단변수(Univariable) - 1변수(독립변수가 하나)
# * 단변량(Univariate) - 1변량(종속변수가 하나)
# * 출처 : [독립변수와 종속변수 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%EB%8F%85%EB%A6%BD%EB%B3%80%EC%88%98%EC%99%80_%EC%A2%85%EC%86%8D%EB%B3%80%EC%88%98)
#     * 실험이나 모델링에서 사용되는 변수는 독립 변수(independent variable), 종속 변수(dependent variable) 혹은 기타로 분류할 수 있다. 독립 변수는 입력값이나 원인을 나타내며, 종속 변수는 결과물이나 효과를 나타낸다.
#     * 기계 학습 혹은 패턴 인식에서는 특징 (feature) 이라고도 한다. 그냥 단순히 입력 변수(input variable)이라고도 한다.
#     * 독립 변수는 설명 변수(Explanatory variable)라고 하기도 한다. 독립 변수로 취급하는 것의 수량이 통계적으로 독립적이지 않을 경우에 한하여 더 선호된다.
#
# ### 수치형
#
# * 수치형 vs 범주형에 따라 표현이 달라지고 여기에서는 수치형 변수를 봅니다.
# * https://seaborn.pydata.org/generated/seaborn.boxplot.html
#
#
# ### box-and-whisker plot | diagram
#
# * [상자 수염 그림 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%EC%83%81%EC%9E%90_%EC%88%98%EC%97%BC_%EA%B7%B8%EB%A6%BC)
# * 가공하지 않은 자료 그대로를 이용하여 그린 것이 아니라, 자료로부터 얻어낸 통계량인 5가지 요약 수치로 그린다.
# * 5가지 요약 수치란 기술통계학에서 자료의 정보를 알려주는 아래의 다섯 가지 수치를 의미한다.
#
#
# 1. 최솟값
# 1. 제 1사분위수
# 1. 제 2사분위수( ), 즉 중앙값
# 1. 제 3 사분위 수( )
# 1. 최댓값
#
# * Box plot 이해하기 :
#     * [박스 플롯에 대하여 :: -[|]- Box and Whisker](https://boxnwhis.kr/2019/02/19/boxplot.html)
#     * [Understanding Boxplots – Towards Data Science](https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51)

# %%
# 라이브러리를 로드합니다.
import pandas as pd
import seaborn as sns

# %%
# tips 데이터셋을 가져옵니다.

tips = sns.load_dataset("tips")
tips.shape
# Out:
# (244, 7)

# %% [markdown]
# ## distplot

# %%
sns.distplot(tips["tip"])

# %% [markdown]
# ## boxplot

# %%
# boxplot 으로 시각화 합니다.
sns.distplot(tips["tip"])
sns.boxplot(tips["tip"])

# %% [markdown]
# ## boxenplot

# %%
sns.boxenplot(tips["tip"])

# %% [markdown]
# ## violinplot

# %%
sns.violinplot(tips["tip"])

# %% [markdown]
# ## subplots
# * distplot, boxplot, boxenplot, violinplot, swarmplot 을 그립니다.

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(15, 8))

sns.distplot(tips["tip"], ax=axes[0])
sns.boxplot(tips["tip"], ax=axes[1])
sns.boxenplot(tips["tip"], ax=axes[2])
sns.violinplot(tips["tip"], ax=axes[3])
sns.swarmplot(tips["tip"], ax=axes[4])

# %% [markdown]
# ## 이상치(outlier) 구하기
# * https://ko.wikipedia.org/wiki/%EC%83%81%EC%9E%90_%EC%88%98%EC%97%BC_%EA%B7%B8%EB%A6%BC
# * IQR = Q3 - Q1
# * outlier
#     * Q3 + 1.5(IQR)
#     * Q1 - 1.5(IQR)

# %%
desc = tips["tip"].describe()
desc
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %%
IQR = desc["75%"] - desc["25%"]
IQR
# Out:
# 1.5624999999999996

# %%
IQR = tips["tip"].quantile(0.75) - tips["tip"].quantile(0.25)
IQR
# Out:
# 1.5624999999999996

# %%
IQR_15 = IQR * 1.5
IQR_15
# Out:
# 2.343749999999999

# %%
desc["75%"] + IQR_15
# Out:
# 5.906249999999998

# %%
desc["25%"] - IQR_15
# Out:
# -0.3437499999999991

# %% [markdown]
# * [The Datasaurus Dozen - Same Stats, Different Graphs | Autodesk Research](https://www.autodeskresearch.com/publications/samestats)
#
# <img src="https://d2f99xq7vri1nk.cloudfront.net/BoxViolinSmaller.gif">
