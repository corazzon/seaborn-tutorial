# %% [markdown]
# ## 단변수
# * 변수가 하나일 때
# * 단변수(Univariable) - 1변수(독립변수가 하나)
# * 단변량(Univariate) - 1변량(종속변수가 하나)
# * 출처 : [독립변수와 종속변수 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%EB%8F%85%EB%A6%BD%EB%B3%80%EC%88%98%EC%99%80_%EC%A2%85%EC%86%8D%EB%B3%80%EC%88%98)
#     * 실험이나 모델링에서 사용되는 변수는 독립 변수(independent variable), 종속 변수(dependent variable) 혹은 기타로 분류할 수 있다. 독립 변수는 입력값이나 원인을 나타내며, 종속 변수는 결과물이나 효과를 나타낸다.
#     * 기계 학습 혹은 패턴 인식에서는 특징 (feature) 이라고도 한다. 그냥 단순히 입력 변수(input variable)이라고도 한다.
#     * 독립 변수는 설명 변수(Explanatory variable)라고 하기도 한다. 독립 변수로 취급하는 것의 수량이 통계적으로 독립적이지 않을 경우에 한하여 더 선호된다.
#
# ### 수치형
#
# * 수치형 vs 범주형에 따라 표현이 달라지고 여기에서는 수치형 변수를 봅니다.
# * https://seaborn.pydata.org/generated/seaborn.distplot.html
#
# ## 도수분포
# 출처 : [도수 분포 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%EB%8F%84%EC%88%98_%EB%B6%84%ED%8F%AC)
#
# 도수 분포(度數分布, frequency distribution)는 표본의 다양한 산출 분포를 보여주는 목록, 표, 그래프이다. 표에 들어가는 각 항목은 특정 그룹이나 주기 안에 값이 발생한 빈도나 횟수를 포함하고 있으며 이러한 방식으로 표는 표본 값의 분포를 요약한다.
#
# ## 히스토그램
# * 출처 : [히스토그램 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%ED%9E%88%EC%8A%A4%ED%86%A0%EA%B7%B8%EB%9E%A8)
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Histogram_of_arrivals_per_minute.svg/1920px-Histogram_of_arrivals_per_minute.svg.png" width="400">
#
# ## 분포
# * 출처 : [확률 분포 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%ED%99%95%EB%A5%A0_%EB%B6%84%ED%8F%AC)
# * <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/8c/Standard_deviation_diagram.svg/700px-Standard_deviation_diagram.svg.png" width="400">
#
#
#
# ### [6 시그마 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/6_%EC%8B%9C%EA%B7%B8%EB%A7%88)
# * 6 시그마는 모토로라가 등록한 상표이다. 시그마(σ)는 원래 정규분포에서 표준편차를 나타내며 6표준편차인 100만 개 중 3.4개의 불량률(Defects per million opportunities, DPMO)을 추구한다는 의미에서 나온 말이다. 실제로 ±6 시그마 수준은 100만 개중 0.002 개의 불량률로서, 6 시그마는 불량 제로를 추구하는 말이다.
#
#
# <img src="https://imgnews.pstatic.net/image/001/2020/06/10/AKR20200610092400004_01_i_P4_20200610135016535.jpg" width=500>
#
# * 이미지 출처 : http://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=001&oid=001&aid=0011668723

# %%
# 라이브러리를 로드합니다.
import seaborn as sns
import pandas as pd

# %%
# tips 데이터셋을 가져옵니다.
tips = sns.load_dataset("tips")
tips.shape
# Out:
# (244, 7)

# %%
# 데이터프레임의 info를 봅니다.
# 이 때, 결측치가 있는지, 데이터의 타입이 무엇인지, 
# 데이터의 행과 열의 갯수는 몇 개인지, 메모리 사이즈는 어느정도인지를 봅니다.

tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %% [markdown]
# ### 시각화의 안 좋은 예

# %%
# 기존 단변량 범주형 데이터에 적용했던 countplot 을 단변량 수치 데이터에 적용해 봅니다.
tips["tip"]
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
sns.countplot(data=tips, x="tip")

# %%
# countplot은 등장하는 모든 값에 대해 빈도수를 세게 됩니다.
# pandas 코드로 표현하면 value_counts 로 셀 수 있습니다.
tips["tip"].nunique()
# Out:
# 123

# %% [markdown]
# ### 데이터 타입에 맞는 시각화

# %%
# distplot 으로 시각화를 합니다. 
# 히스토그램과 kdeplot을 함께 그립니다.
sns.distplot(tips["tip"], rug=True)

# %%
# bin 의 갯수를 조절해 봅니다. bin 1개 일 때

sns.distplot(tips["tip"], bins=1)

# %%
# bin 의 갯수를 조절해 봅니다. bin 10개 일 때

sns.distplot(tips["tip"], bins=10)

# %%
# kde = False 옵션으로 그려봅니다.
sns.distplot(tips["tip"], kde=False)

# %%
# hist = False 옵션으로 그려봅니다.
sns.distplot(tips["tip"], hist=False, rug=True)

# %%
# kdeplot 으로 그리기 
# kde는 KDE(kernel density estimation)의 약자
sns.kdeplot(tips["tip"], shade=True)

# %%
sns.kdeplot(tips["tip"], cumulative=True, shade=True)

# %%
sns.kdeplot(tips["tip"], shade=True, vertical=True)

# %%
h = tips.hist()
